# %%
import tifffile
from pathlib import Path
from rich import print

# %%
path = Path("/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/")
# path = Path("/Users/fdrgsp/Documents/git/qpm/test_data/input_phc/")
files = list(sorted(path.glob("*.tif")))
print(files)
# Out:
# [
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos0.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos1.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos10.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos11.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos2.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos3.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos4.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos5.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos6.ome.tif'),
#     PosixPath('/Users/fdrgsp/Desktop/E_Coli_MP_1_ph_contrast/E_Coli_MP_1_MMStack_Pos7.ome.tif'),
# ...

# %%
file = files[0]
with tifffile.TiffFile(file) as tif:
    positions = tif.series
    print(positions)

    for pos in positions:
        image = pos.asarray()
        print(image.shape)
        print(image.ndim)
# Out:
# [
#     <tifffile.TiffPageSeries 0 ome>,
#     <tifffile.TiffPageSeries 1 ome>,
#     <tifffile.TiffPageSeries 2 ome>,
#     <tifffile.TiffPageSeries 3 ome>,
#     <tifffile.TiffPageSeries 4 ome>,
#     <tifffile.TiffPageSeries 5 ome>,
#     <tifffile.TiffPageSeries 6 ome>,
#     <tifffile.TiffPageSeries 7 ome>,
#     <tifffile.TiffPageSeries 8 ome>,
#     <tifffile.TiffPageSeries 9 ome>,
#     <tifffile.TiffPageSeries 10 ome>,
#     <tifffile.TiffPageSeries 11 ome>
# ]
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
# (2048, 2048)
# 2
